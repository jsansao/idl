# %% [markdown]
# <a href="https://colab.research.google.com/github/jsansao/idl/blob/main/TrabalhoPratico2_IDL_2023_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Trabalho Prático 2  - 2023-2 - Comparação de métodos (LTSM, GRU e CONV1D)
#
# Vamos comparar os métodos GRU, LTSM e CONV1D na classificação de manchetes de notícias em quatro categorias (World, Sport, Business, Sci/Tech).
#
# Determine as acurácias de treinamento, validação para cada método e número de parâmetros de cada modelo.
#
# Note que a camada de saída deve ter 4 neurônios para se usar uma classificação com softmax.

# %%
import tensorflow as tf
print(tf.__version__)

# !pip install -q tensorflow-datasets
# Out:
# 2.14.0

# %%
# !pip install tfds-nightly

# %% [markdown]
# ## Carregamento do dataset

# %%
import tensorflow_datasets as tfds
imdb, info = tfds.load("AgNewsSubset", with_info=True, as_supervised=True)
# Out:
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# ...
# Generating train examples...:   0%|          | 0/120000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/ag_news_subset/1.0.0.incompleteZBER23/ag_news_subset-train.tfrecord*...:  …
# Generating test examples...:   0%|          | 0/7600 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/ag_news_subset/1.0.0.incompleteZBER23/ag_news_subset-test.tfrecord*...:   …
# Dataset ag_news_subset downloaded and prepared to /root/tensorflow_datasets/ag_news_subset/1.0.0. Subsequent calls will reuse this data.

# %% [markdown]
# ## Pré-processamento

# %%
import numpy as np

train_data, test_data = imdb['train'], imdb['test']

training_sentences = []
training_labels = []

testing_sentences = []
testing_labels = []

# str(s.tonumpy()) is needed in Python3 instead of just s.numpy()
for s,l in train_data:
  training_sentences.append(str(s.numpy()))
  training_labels.append(l.numpy())

for s,l in test_data:
  testing_sentences.append(str(s.numpy()))
  testing_labels.append(l.numpy())

training_labels_final = np.array(training_labels)
testing_labels_final = np.array(testing_labels)

# %%
vocab_size = 10000
embedding_dim = 16
max_length = 120
trunc_type='post'
oov_tok = "<OOV>"


from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

tokenizer = Tokenizer(num_words = vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(training_sentences)
word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(training_sentences)
padded = pad_sequences(sequences,maxlen=max_length, truncating=trunc_type)

testing_sequences = tokenizer.texts_to_sequences(testing_sentences)
testing_padded = pad_sequences(testing_sequences,maxlen=max_length)

# %%
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])

def decode_review(text):
    return ' '.join([reverse_word_index.get(i, '?') for i in text])

print(decode_review(padded[1]))
print(training_sentences[1])
# Out:
# ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? b'reuters major league baseball monday announced a decision on the appeal filed by chicago cubs pitcher kerry wood regarding a suspension stemming from an incident earlier this season '
# b'Reuters - Major League Baseball\\Monday announced a decision on the appeal filed by Chicago Cubs\\pitcher Kerry Wood regarding a suspension stemming from an\\incident earlier this season.'

# %% [markdown]
# # 1 - GRU

# %% [markdown]
# # 2 - LTSM

# %% [markdown]
# # 3 - Conv1D
