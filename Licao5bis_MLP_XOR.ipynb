# %% [markdown]
# <a href="https://colab.research.google.com/github/jsansao/idl/blob/main/Licao5bis_MLP_XOR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lição 5bis - Conjuntos não linearmente separáveis
#
# Nesta lição, vamos ver a aplicação das redes neurais em um problema não linearmente separável.
#
# Temos duas classes, com coordenadas bi-dimensionais.
#
# O conjunto 0 está nos quadrantes I e III. O conjunto 1 está nos quadrantes II e IV.

# %% [markdown]
# ## Carregando as bibliotecas

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt

# %% [markdown]
# ## Carregando o conjunto de dados

# %%
# !wget https://github.com/jsansao/dlvc/raw/main/Licao2bis_MLP_XOR.tar.gz
# !tar -zxvf Licao2bis_MLP_XOR.tar.gz
# Out:
# --2022-04-12 20:21:11--  https://github.com/jsansao/dlvc/raw/main/Licao2bis_MLP_XOR.tar.gz
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/jsansao/dlvc/main/Licao2bis_MLP_XOR.tar.gz [following]
# --2022-04-12 20:21:12--  https://raw.githubusercontent.com/jsansao/dlvc/main/Licao2bis_MLP_XOR.tar.gz
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 54041 (53K) [application/octet-stream]
# Saving to: ‘Licao2bis_MLP_XOR.tar.gz’
#
# Licao2bis_MLP_XOR.t 100%[===================>]  52.77K  --.-KB/s    in 0.007s
#
# 2022-04-12 20:21:12 (7.47 MB/s) - ‘Licao2bis_MLP_XOR.tar.gz’ saved [54041/54041]
#
# train_label.csv
# train_data.csv
# test_label.csv
# test_data.csv

# %% [markdown]
# ## Lendo os dados em csv

# %%
from numpy import genfromtxt
train_data = genfromtxt('train_data.csv', delimiter=',')
train_label = genfromtxt('train_label.csv', delimiter=',')

test_data = genfromtxt('test_data.csv', delimiter=',')
test_label = genfromtxt('test_label.csv', delimiter=',')

# %% [markdown]
# ## A dispersão dos dados (treinamento e teste)

# %%
plt.scatter(train_data[:,0], train_data[:,1], c=train_label , alpha=0.5, cmap='jet')
plt.show()
plt.scatter(test_data[:,0], test_data[:,1], c=test_label , alpha=0.5, cmap='jet')
plt.show()

# %% [markdown]
# ## Primeira tentativa: Rede neural com apenas um neurônio

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[2])])
model.compile(optimizer='sgd', loss='mean_squared_error', metrics=['accuracy'])

model.fit(train_data, train_label, epochs=50)

model.summary()
# Out:
# Epoch 1/50
# 125/125 [==============================] - 1s 1ms/step - loss: 0.4063 - accuracy: 0.5383
# Epoch 2/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2787 - accuracy: 0.5000
# Epoch 3/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2578 - accuracy: 0.5000
# Epoch 4/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2522 - accuracy: 0.5000
# Epoch 5/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2507 - accuracy: 0.4997
# Epoch 6/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2503 - accuracy: 0.4980
# Epoch 7/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.4618
# Epoch 8/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.4760
# Epoch 9/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2503 - accuracy: 0.4700
# Epoch 10/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.4830
# Epoch 11/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.4927
# Epoch 12/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.5065
# Epoch 13/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.4827
# Epoch 14/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.5157
# Epoch 15/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2503 - accuracy: 0.5008
# Epoch 16/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.4905
# Epoch 17/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.4490
# Epoch 18/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.4620
# Epoch 19/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.4983
# Epoch 20/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.5235
# Epoch 21/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.4560
# Epoch 22/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2501 - accuracy: 0.5610
# Epoch 23/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.4803
# Epoch 24/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.4385
# Epoch 25/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.4790
# Epoch 26/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.4500
# Epoch 27/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.5113
# Epoch 28/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.4403
# Epoch 29/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.4983
# Epoch 30/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.4757
# Epoch 31/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.4570
# Epoch 32/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.5052
# Epoch 33/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.4950
# Epoch 34/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.5027
# Epoch 35/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.4960
# Epoch 36/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.4868
# Epoch 37/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.5077
# Epoch 38/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.4785
# Epoch 39/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.4555
# Epoch 40/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.5033
# Epoch 41/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.5120
# Epoch 42/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.5098
# Epoch 43/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.4970
# Epoch 44/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.4922
# Epoch 45/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.4470
# Epoch 46/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.5130
# Epoch 47/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.4888
# Epoch 48/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.4922
# Epoch 49/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.4672
# Epoch 50/50
# 125/125 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.4988
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 3
#
# =================================================================
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Dispersão da predição para o conjunto de teste

# %%
test_predict = model.predict(test_data)

plt.scatter(test_data[:,0], test_data[:,1], c=test_predict , cmap='jet')
plt.show()

# %% [markdown]
# ## Superfície gerada pela rede (predição)

# %%
nx = 100
ny = 100
x = np.linspace(-1, 1, nx)
y = np.linspace(-1, 1, ny)
xv,yv = np.meshgrid(x, y, sparse=False, indexing='ij')
test_grid_x =  xv.flatten()
test_grid_y =  yv.flatten()

grid_list = np.append(test_grid_x, test_grid_y, axis=0)

test_grid = np.reshape(grid_list, (2, -1))

test_predict4 = model.predict(test_grid.T)

plt.scatter(test_grid[0,:], test_grid[1,:], c=test_predict4, cmap='jet')
plt.show()

# %% [markdown]
# ## Adição de camada

# %%
model2 = tf.keras.Sequential([tf.keras.layers.Dense(16, activation=tf.nn.relu, input_shape=[2]),                                                                     
                              tf.keras.layers.Dense(1, activation=tf.nn.sigmoid)])
model2.compile(optimizer='sgd', loss='mean_squared_error', metrics=['accuracy'])

#model2.fit(train_data, train_label, epochs=500)


history = model2.fit(train_data, train_label,
                    batch_size=20,
                    epochs=40,
                    verbose=1,
                    validation_data=(test_data, test_label))

model2.summary()
# Out:
# Epoch 1/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2540 - accuracy: 0.4970 - val_loss: 0.2446 - val_accuracy: 0.5272
# Epoch 2/40
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2364 - accuracy: 0.5807 - val_loss: 0.2278 - val_accuracy: 0.6875
# Epoch 3/40
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2202 - accuracy: 0.7793 - val_loss: 0.2124 - val_accuracy: 0.9337
# Epoch 4/40
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2053 - accuracy: 0.9797 - val_loss: 0.1980 - val_accuracy: 0.9960
# Epoch 5/40
# 200/200 [==============================] - 0s 2ms/step - loss: 0.1913 - accuracy: 0.9987 - val_loss: 0.1845 - val_accuracy: 0.9992
# Epoch 6/40
# 200/200 [==============================] - 0s 2ms/step - loss: 0.1781 - accuracy: 1.0000 - val_loss: 0.1716 - val_accuracy: 1.0000
# Epoch 7/40
# 200/200 [==============================] - 1s 3ms/step - loss: 0.1655 - accuracy: 1.0000 - val_loss: 0.1593 - val_accuracy: 1.0000
# Epoch 8/40
# 200/200 [==============================] - 1s 3ms/step - loss: 0.1533 - accuracy: 1.0000 - val_loss: 0.1474 - val_accuracy: 1.0000
# Epoch 9/40
# 200/200 [==============================] - 0s 2ms/step - loss: 0.1415 - accuracy: 1.0000 - val_loss: 0.1359 - val_accuracy: 1.0000
# Epoch 10/40
# 200/200 [==============================] - 1s 3ms/step - loss: 0.1303 - accuracy: 1.0000 - val_loss: 0.1250 - val_accuracy: 1.0000
# Epoch 11/40
# 200/200 [==============================] - 1s 3ms/step - loss: 0.1196 - accuracy: 1.0000 - val_loss: 0.1146 - val_accuracy: 1.0000
# Epoch 12/40
# 200/200 [==============================] - 1s 3ms/step - loss: 0.1095 - accuracy: 1.0000 - val_loss: 0.1048 - val_accuracy: 1.0000
# Epoch 13/40
# 200/200 [==============================] - 1s 3ms/step - loss: 0.1000 - accuracy: 1.0000 - val_loss: 0.0956 - val_accuracy: 1.0000
# Epoch 14/40
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0912 - accuracy: 1.0000 - val_loss: 0.0871 - val_accuracy: 1.0000
# Epoch 15/40
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0830 - accuracy: 1.0000 - val_loss: 0.0794 - val_accuracy: 1.0000
# Epoch 16/40
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0756 - accuracy: 1.0000 - val_loss: 0.0723 - val_accuracy: 1.0000
# Epoch 17/40
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0689 - accuracy: 1.0000 - val_loss: 0.0659 - val_accuracy: 1.0000
# Epoch 18/40
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0628 - accuracy: 1.0000 - val_loss: 0.0602 - val_accuracy: 1.0000
# Epoch 19/40
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0574 - accuracy: 1.0000 - val_loss: 0.0550 - val_accuracy: 1.0000
# Epoch 20/40
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0525 - accuracy: 1.0000 - val_loss: 0.0504 - val_accuracy: 1.0000
# Epoch 21/40
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0482 - accuracy: 1.0000 - val_loss: 0.0463 - val_accuracy: 1.0000
# Epoch 22/40
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0443 - accuracy: 1.0000 - val_loss: 0.0427 - val_accuracy: 1.0000
# Epoch 23/40
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0408 - accuracy: 1.0000 - val_loss: 0.0394 - val_accuracy: 1.0000
# Epoch 24/40
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0377 - accuracy: 1.0000 - val_loss: 0.0365 - val_accuracy: 1.0000
# Epoch 25/40
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0350 - accuracy: 1.0000 - val_loss: 0.0339 - val_accuracy: 1.0000
# Epoch 26/40
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0325 - accuracy: 1.0000 - val_loss: 0.0315 - val_accuracy: 1.0000
# Epoch 27/40
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0303 - accuracy: 1.0000 - val_loss: 0.0294 - val_accuracy: 1.0000
# Epoch 28/40
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0283 - accuracy: 1.0000 - val_loss: 0.0275 - val_accuracy: 1.0000
# Epoch 29/40
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0265 - accuracy: 1.0000 - val_loss: 0.0258 - val_accuracy: 1.0000
# Epoch 30/40
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0248 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 1.0000
# Epoch 31/40
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0234 - accuracy: 1.0000 - val_loss: 0.0228 - val_accuracy: 1.0000
# Epoch 32/40
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0220 - accuracy: 1.0000 - val_loss: 0.0215 - val_accuracy: 1.0000
# Epoch 33/40
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0208 - accuracy: 1.0000 - val_loss: 0.0204 - val_accuracy: 1.0000
# Epoch 34/40
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0197 - accuracy: 1.0000 - val_loss: 0.0193 - val_accuracy: 1.0000
# Epoch 35/40
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0186 - accuracy: 1.0000 - val_loss: 0.0183 - val_accuracy: 1.0000
# Epoch 36/40
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0177 - accuracy: 1.0000 - val_loss: 0.0174 - val_accuracy: 1.0000
# Epoch 37/40
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0168 - accuracy: 1.0000 - val_loss: 0.0166 - val_accuracy: 1.0000
# Epoch 38/40
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0160 - accuracy: 1.0000 - val_loss: 0.0158 - val_accuracy: 1.0000
# Epoch 39/40
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0153 - accuracy: 1.0000 - val_loss: 0.0151 - val_accuracy: 1.0000
# Epoch 40/40
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.0145 - val_accuracy: 1.0000
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, 16)                48
#
#  dense_2 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 65
# Trainable params: 65
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Evolução do treinamento

# %%
fig, ax = plt.subplots(1,2, figsize=(16,8))
ax[0].plot(history.history['loss'], color='b', label="Training loss")
ax[0].plot(history.history['val_loss'], color='r', label="validation loss",axes =ax[0])
legend = ax[0].legend(loc='best', shadow=True)

ax[1].plot(history.history['accuracy'], color='b', label="Training accuracy")
ax[1].plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
legend = ax[1].legend(loc='best', shadow=True)

# %% [markdown]
# ## Dispersão do conjunto de teste (predição)

# %%
test_predict2 = model2.predict(test_data)

plt.scatter(test_data[:,0], test_data[:,1], c=test_predict2, cmap='jet')
plt.show()

# %% [markdown]
# ## Superfície gerada pela rede (predição)

# %%
nx = 100
ny = 100
x = np.linspace(-1, 1, nx)
y = np.linspace(-1, 1, ny)
xv,yv = np.meshgrid(x, y, sparse=False, indexing='ij')
test_grid_x =  xv.flatten()
test_grid_y =  yv.flatten()

grid_list = np.append(test_grid_x, test_grid_y, axis=0)

test_grid = np.reshape(grid_list, (2, -1))

test_predict3 = model2.predict(test_grid.T)

plt.scatter(test_grid[0,:], test_grid[1,:], c=test_predict3, cmap='jet')
plt.show()
